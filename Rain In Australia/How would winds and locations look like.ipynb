# %%
# %run imports.ipynb
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_27816\3443027451.py:12: DeprecationWarning: `import pandas_profiling` is going to be deprecated by April 1st. Please use `import ydata_profiling` instead.
#   from pandas_profiling import ProfileReport

# %%
preprocessor = Preprocessor('median', 'mode', 
                            roll_cols=standard_roll_cols, 
                            roll_strategies=standard_roll_strategies,
                            roll_period=7)
data = preprocessor.preprocess(train, visualize=True)

# %%
from dash import Dash
import plotly.express as px
import seaborn as sns

# %%
scatter_data = data[['Humidity3pm', 'RainTomorrow']].dropna().sample(n=300)

# %%
sns.violinplot(x=scatter_data.Humidity3pm, y=scatter_data.RainTomorrow.astype(str))
# Out:
# <AxesSubplot: xlabel='Humidity3pm', ylabel='RainTomorrow'>

# %%
scatter_data
# Out:
#         Humidity3pm RainTomorrow
# 35677          63.0            0
# 93644          81.0            1
# 22703          83.0            1
# 104555         36.0            0
# 16359          51.0            0
# ...             ...          ...
# 108134         74.0            0
# 4625           16.0            0
# 37038          22.0            0
# 67585          74.0            0
# 66306          40.0            0
#
# [300 rows x 2 columns]

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df = px.data.tips()
fig = px.violin(scatter_data, y='Humidity3pm', x=None,
                box=True, points='all',
                color='RainTomorrow', violinmode='overlay')
fig
# Out:
# <div>                            <div id="ddd5b261-0647-44f1-b4df-b778639b9ab7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddd5b261-0647-44f1-b4df-b778639b9ab7")) {                    Plotly.newPlot(                        "ddd5b261-0647-44f1-b4df-b778639b9ab7",                        [{"alignmentgroup":"True","box":{"visible":true},"hovertemplate":"RainTomorrow=0<br>Humidity3pm=%{y}<extra></extra>","legendgroup":"0","marker":{"color":"#636efa"},"name":"0","offsetgroup":"0","orientation":"v","points":"all","scalegroup":"True","showlegend":true,"x0":" ","xaxis":"x","y":[63.0,36.0,51.0,18.0,50.0,17.0,49.0,66.0,67.0,47.0,18.0,41.0,61.0,57.0,48.0,54.0,69.0,37.0,63.0,52.0,17.0,61.0,46.0,44.0,43.0,54.0,9.0,19.0,42.0,45.0,20.0,58.0,45.0,51.0,82.0,65.0
# ...

# %%
 px.data.tips()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
